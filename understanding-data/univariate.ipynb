# %%
# This is part of EDA (Exploratory Data Analysis)
# In univariate analysis the focus is mainly on creating graphs to understand data
# for charts learn matplotlib and seaborn

# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("./dataset/matches.csv")

# %%
df.sample(5)
# Out:
#           id   season   city        date match_type player_of_match  \
# 868  1254094     2021  Dubai  2021-10-07     League        KL Rahul
# 928  1304099     2022   Pune  2022-05-07     League      Avesh Khan
# 800  1216544  2020/21    NaN  2020-10-25     League      RD Gaikwad
# 711  1175371     2019  Delhi  2019-04-04     League     JM Bairstow
# 774  1216519  2020/21    NaN  2020-10-05     League        AR Patel
#
#                                              venue  \
# 868            Dubai International Cricket Stadium
# 928  Maharashtra Cricket Association Stadium, Pune
# 800            Dubai International Cricket Stadium
# 711                           Arun Jaitley Stadium
# 774            Dubai International Cricket Stadium
#
#                            team1                        team2  \
# 868          Chennai Super Kings                 Punjab Kings
# 928         Lucknow Super Giants        Kolkata Knight Riders
# ...

# %% [markdown]
# # Categorical Data

# %%
# countplot
winner = df[df['toss_winner'] == df['winner']]
sns.countplot(data=winner['toss_winner']) # not working correctly :(



# toss_decision['toss_decision'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='count', ylabel='toss_winner'>

# %%
winner['toss_decision'].value_counts().plot(kind='pie', autopct='%.2f')
# Out:
# <Axes: ylabel='toss_decision'>

# %% [markdown]
# # Numerical Data

# %%
# Histogram
import matplotlib.pyplot as plt

plt.hist(winner['target_runs'])
# Out:
# (array([  5.,   8.,  22.,  57., 131., 192., 107.,  25.,   5.,   2.]),
#  array([ 43.,  66.,  89., 112., 135., 158., 181., 204., 227., 250., 273.]),
#  <BarContainer object of 10 artists>)

# %%
# Distplot - this is improvement of histogram

sns.histplot(winner["target_runs"], kde=True, stat="density")
# Out:
# <Axes: xlabel='target_runs', ylabel='Density'>

# %%
# box plot - gives you 5 number summary
# could be used to identify outliers
sns.boxplot(winner['target_runs'], orient='y')
# Out:
# <Axes: xlabel='target_runs'>

# %%
# skewness of data
df['target_runs'].skew()
# Out:
# -0.24348256081327094

# %%
df['target_runs'].describe()
# Out:
# count    1092.000000
# mean      165.684066
# std        33.427048
# min        43.000000
# 25%       146.000000
# 50%       166.000000
# 75%       187.000000
# max       288.000000
# Name: target_runs, dtype: float64
